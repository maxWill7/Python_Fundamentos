# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print('alo mundo')
# Out:
# alo mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = input ('digite um número')
print('o numero informado foi' , numero)
# Out:
# o numero informado foi 5

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
numero = input ('digite um número')
numero2 = input ('digite um número')
soma = (int(numero) + int(numero2))
print(f'o número informado foi {soma}')
# Out:
# o número informado foi 10

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nota = input ('qual foi a sua nota?')
nota2 = input ('qual foi sua nota?')
nota3 = input ('qual foi sua nota?')
nota4 = input ('qual foi sua nota?')
media_nota = (int(nota) + int(nota2) + int(nota3) + int(nota4)) / 4

print(media_nota)
# Out:
# 8.75

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metros = input('digite a quantos metros?')
centimetros = (int (metros) * 100)
print('o comprimento em centímetros é:', centimetros, 'cm')
# Out:
# o comprimento em centímetros é: 10000 cm

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura_sala = 20
comprimento_sala = 30
area_sala = (largura_sala * comprimento_sala) 

print(area_sala ,'metros quadrados')
# Out:
# 600 metros quadrados

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
ganhos_por_hr = float(input('quantos você ganha por hora?'))
horas_por_mes = float(input('quantas horas trabalhadas por mês?'))
salario_mes = ganhos_por_hr * horas_por_mes

print(salario_mes)
# Out:
# 2392.0

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
graus_fahrenheit = float(5 / 9) - 32
graus_celsius = graus_fahrenheit

print('temperatura em graus celsius é:' , graus_celsius)
# Out:
# temperatura em graus celsius é: -31.444444444444443

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
graus_celsius = float(9 / 5) + 32
graus_fahrenheit = graus_celsius

print (f'a temperatura em graus fahrenheit é:' , {graus_fahrenheit})
# Out:
# a temperatura em graus fahrenheit é: {33.8}

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = 72.7 - 58
peso = altura

print(peso)
# Out:
# 14.700000000000003

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
altura_homem = 72.7 - 58
peso_homem = altura_homem
altura_mulher = 62.1 - 44.7
peso_mulher = altura_mulher

print('peso do homem é:' , peso_homem)
print('peso da mulher é:' , peso_mulher)
# Out:
# peso do homem é: 14.700000000000003
# peso da mulher é: 17.4

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
input('quantos vc ganha por hora?')
input('quantas horas você trabalha por mês?')
# Out:
# '184'

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario_mes = 2000.00
horas_por_mes = 184
salario_por_hr = salario_mes / horas_por_mes

print(salario_por_hr)
# Out:
# 10.869565217391305

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
salario = 2000.00
salario_desconto_ir = salario - 11

print(salario_desconto_ir)
# Out:
# 1989.0

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
salario = 2000.00
desconto_inss = salario - 8

print(desconto_inss)
# Out:
# 1992.0

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
salario = 2000.00
desconto_sindicado = salario - 5

print(desconto_sindicado)
# Out:
# 1995.0

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
salario = 2000.00
salario_desconto = salario - 24
salario_liquido = salario_desconto

print(salario_liquido)
# Out:
# 1976.0

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
metros_quadrados = int(input ('didgite o tamanha da área:'))
tinta = ('18 litros')
preco = 80.00
qtde_latas = metros_quadrados / 18
preco_total = preco * qtde_latas

print('quantidade de lata é ' , qtde_latas , 'no valor de' , preco_total)
# Out:
# quantidade de lata é  33.333333333333336 no valor de 2666.666666666667

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
arquivo = float(input('qual o tamanho do arquivo em MB?'))
velocidade_internet = float(input('digite a velocidade do link em mbps:')) 
tempo_download = arquivo / 1.8 + velocidade_internet
tempo_arquivo = (tempo_download , 'minutos')

print(tempo_arquivo )
# Out:
# (25.555555555555557, 'minutos')
